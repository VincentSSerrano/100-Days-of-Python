# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentSSerrano/100-Days-of-Python/blob/main/Day_2/Tip_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hello"[4]
print("123" + " 456")
# Out:
# 123 456

# %%
num_char = len(input("What is your name? "))
new_num_char = str(num_char)
print("Your name has " + new_num_char + " characters." )
# Out:
# What is your name? Vincent
# Your name has 7 characters.

# %% [markdown]
# test

# %%
sum = input("Type a two digit number: ")
ans = int(sum[0]) + int(sum[1])

print(ans)
print(type(int(sum[0]+sum[1])))
print((int(sum[0])+(int(sum[1]))))
# Out:
# Type a two digit number: 69
# 15
# <class 'int'>
# 15

# %%
#PEMDAS SLR
# ()
# **
# * /
# + -

# %% [markdown]
# BMI calculator test

# %%
height = input("enter your height in m: ")
weight = input("enter your weight in kg: ")

a = int(weight)
b = float(height) ** 2
bmi = a / b
bmi_int = int(bmi)
test = int(weight) / float(height) ** 2
print(test)
print(type(bmi))
print(bmi_int)
# print(bmi)
# Out:
# enter your height in m: 1.75
# enter your weight in kg: 80
# 26.122448979591837
# <class 'float'>
# 26

# %%
# result = 4/2
# result /= 2
# print(result)

score = 0
# score +=1
# print(score)
# print("Your score is " + score )

height = 1.8
isWinning = True
#f-String
print(f"your score is {score}, you height is {height}, you are winning is {isWinning}")
# Out:
# your score is 0, you height is 1.8, you are winning is True

# %% [markdown]
# Exercise

# %%
age = input("what is your current age? ")
# 90 years

age = int(age)
left = 90
d = 365
w = 52
m = 12
days_left= (left * d) -  (age * d)
weeks_left = (left * w) - (age * w)
months_left = (left * m) - (age * m)
print(f"you have {days_left} days, {weeks_left} weeks and {months_left} months left")
# Out:
# what is your current age? 25
# you have 23725 days, 3380 weeks and 780 months left

# %% [markdown]
# Final Project - Tip Calculator

# %%
print("Welcome to the tip calculator!")
bill = float(input("What was the total bill? $"))
tip = int(input("What percentage tip would you like to give? 10, 12, or 15? "))
split = int(input("How many people to split the bill? "))

total = bill + (tip/100 *bill)
hm = total/split
print(f"Each person should pay: ${hm:.2f}")
# Out:
# Welcome to the tip calculator!
# What was the total bill? $124.56
# What percentage tip would you like to give? 10, 12, or 15? 12
# How many people to split the bill? 7
# Each person should pay: $19.93
